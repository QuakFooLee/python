# %% [markdown]
# <a href="https://colab.research.google.com/github/QuakFooLee/python/blob/main/StockRecommendation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install yahoo_fin
# Out:
# Requirement already satisfied: yahoo_fin in /usr/local/lib/python3.10/dist-packages (0.8.9.1)
# Requirement already satisfied: requests-html in /usr/local/lib/python3.10/dist-packages (from yahoo_fin) (0.10.0)
# Requirement already satisfied: feedparser in /usr/local/lib/python3.10/dist-packages (from yahoo_fin) (6.0.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from yahoo_fin) (2.32.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from yahoo_fin) (2.1.4)
# Requirement already satisfied: sgmllib3k in /usr/local/lib/python3.10/dist-packages (from feedparser->yahoo_fin) (1.0.0)
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas->yahoo_fin) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->yahoo_fin) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->yahoo_fin) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->yahoo_fin) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->yahoo_fin) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->yahoo_fin) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->yahoo_fin) (1.26.19)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->yahoo_fin) (2024.7.4)
# Requirement already satisfied: pyquery in /usr/local/lib/python3.10/dist-packages (from requests-html->yahoo_fin) (2.0.0)
# Requirement already satisfied: fake-useragent in /usr/local/lib/python3.10/dist-packages (from requests-html->yahoo_fin) (1.5.1)
# Requirement already satisfied: parse in /usr/local/lib/python3.10/dist-packages (from requests-html->yahoo_fin) (1.20.2)
# Requirement already satisfied: bs4 in /usr/local/lib/python3.10/dist-packages (from requests-html->yahoo_fin) (0.0.2)
# Requirement already satisfied: w3lib in /usr/local/lib/python3.10/dist-packages (from requests-html->yahoo_fin) (2.2.1)
# Requirement already satisfied: pyppeteer>=0.0.14 in /usr/local/lib/python3.10/dist-packages (from requests-html->yahoo_fin) (2.0.0)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in /usr/local/lib/python3.10/dist-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (1.4.4)
# Requirement already satisfied: importlib-metadata>=1.4 in /usr/local/lib/python3.10/dist-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (8.2.0)
# Requirement already satisfied: pyee<12.0.0,>=11.0.0 in /usr/local/lib/python3.10/dist-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (11.1.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (4.66.5)
# Requirement already satisfied: websockets<11.0,>=10.0 in /usr/local/lib/python3.10/dist-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (10.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->yahoo_fin) (1.16.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from bs4->requests-html->yahoo_fin) (4.12.3)
# Requirement already satisfied: lxml>=2.1 in /usr/local/lib/python3.10/dist-packages (from pyquery->requests-html->yahoo_fin) (4.9.4)
# Requirement already satisfied: cssselect>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from pyquery->requests-html->yahoo_fin) (1.2.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests-html->yahoo_fin) (3.19.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from pyee<12.0.0,>=11.0.0->pyppeteer>=0.0.14->requests-html->yahoo_fin) (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->bs4->requests-html->yahoo_fin) (2.5)

# %%
import pandas as pd
import yfinance as yf
from datetime import datetime, timedelta

# Load the list of stocks from the Excel file
stock_list_path = r"StockList.xlsx"
stocks_df = pd.read_excel(stock_list_path)

# Define the date threshold for the last 90 days
date_threshold = datetime.now() - timedelta(days=90)

# Define a function to fetch analyst recommendations using 'upgrades_downgrades'
def get_analyst_recommendations(stock_ticker):
    try:
        stock = yf.Ticker(stock_ticker)
        recommendations = stock.upgrades_downgrades
        if recommendations is not None:
            print(f"Columns available in {stock_ticker} recommendations: {recommendations.columns}")
            recommendations = recommendations.reset_index()
            recommendations['Stock'] = stock_ticker

            # Attempt to filter by date, if available
            if 'Date' in recommendations.columns:
                recommendations['Date'] = recommendations['Date'].apply(lambda x: x.date() if isinstance(x, datetime) else x)
                recommendations = recommendations[recommendations['Date'] >= date_threshold.date()]
            return recommendations
        else:
            print(f"No recommendations found for {stock_ticker}")
            return pd.DataFrame()
    except Exception as e:
        print(f"Error processing {stock_ticker}: {e}")
        return pd.DataFrame()

# Create an empty DataFrame to hold all recommendations
all_recommendations = pd.DataFrame()

# Loop through each stock in the list and fetch its recommendations
for index, row in stocks_df.iterrows():
    stock_ticker = row['QuoteSymbol']
    stock_recommendations = get_analyst_recommendations(stock_ticker)
    all_recommendations = pd.concat([all_recommendations, stock_recommendations])


# Save the combined DataFrame to an Excel file
output_file_path = r'StockResults.xlsx'
all_recommendations.to_excel(output_file_path, index=False)

# Display the result
print(f"Total recommendations fetched: {len(all_recommendations)}")
all_recommendations
# Out:
# Columns available in AAPL recommendations: Index(['Firm', 'ToGrade', 'FromGrade', 'Action'], dtype='object')
# Columns available in AMAT recommendations: Index(['Firm', 'ToGrade', 'FromGrade', 'Action'], dtype='object')
# Columns available in AMC recommendations: Index(['Firm', 'ToGrade', 'FromGrade', 'Action'], dtype='object')
# Columns available in AMD recommendations: Index(['Firm', 'ToGrade', 'FromGrade', 'Action'], dtype='object')
# Columns available in AMZN recommendations: Index(['Firm', 'ToGrade', 'FromGrade', 'Action'], dtype='object')
# Columns available in ARM recommendations: Index(['Firm', 'ToGrade', 'FromGrade', 'Action'], dtype='object')
# Columns available in AVGO recommendations: Index(['Firm', 'ToGrade', 'FromGrade', 'Action'], dtype='object')
# Columns available in BAC recommendations: Index(['Firm', 'ToGrade', 'FromGrade', 'Action'], dtype='object')
# Columns available in CLSK recommendations: Index(['Firm', 'ToGrade', 'FromGrade', 'Action'], dtype='object')
# Columns available in CNQ recommendations: Index(['Firm', 'ToGrade', 'FromGrade', 'Action'], dtype='object')
# Columns available in COIN recommendations: Index(['Firm', 'ToGrade', 'FromGrade', 'Action'], dtype='object')
# Columns available in DELL recommendations: Index(['Firm', 'ToGrade', 'FromGrade', 'Action'], dtype='object')
# ERROR:yfinance:404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/DJT?modules=upgradeDowngradeHistory&corsDomain=finance.yahoo.com&formatted=false&symbol=DJT&crumb=hupYAKrbOMB
# Columns available in DJT recommendations: RangeIndex(start=0, stop=0, step=1)
# Columns available in DOL.TO recommendations: Index(['Firm', 'ToGrade', 'FromGrade', 'Action'], dtype='object')
# Columns available in EA recommendations: Index(['Firm', 'ToGrade', 'FromGrade', 'Action'], dtype='object')
# Columns available in ENB recommendations: Index(['Firm', 'ToGrade', 'FromGrade', 'Action'], dtype='object')
# Columns available in ENB.TO recommendations: Index(['Firm', 'ToGrade', 'FromGrade', 'Action'], dtype='object')
# Columns available in FSLR recommendations: Index(['Firm', 'ToGrade', 'FromGrade', 'Action'], dtype='object')
# Columns available in GME recommendations: Index(['Firm', 'ToGrade', 'FromGrade', 'Action'], dtype='object')
# Columns available in GOOGL recommendations: Index(['Firm', 'ToGrade', 'FromGrade', 'Action'], dtype='object')
# Columns available in INTC recommendations: Index(['Firm', 'ToGrade', 'FromGrade', 'Action'], dtype='object')
# ERROR:yfinance:404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/L.TO?modules=upgradeDowngradeHistory&corsDomain=finance.yahoo.com&formatted=false&symbol=L.TO&crumb=hupYAKrbOMB
# Columns available in L.TO recommendations: RangeIndex(start=0, stop=0, step=1)
# Columns available in MARA recommendations: Index(['Firm', 'ToGrade', 'FromGrade', 'Action'], dtype='object')
# Columns available in MEG.TO recommendations: Index(['Firm', 'ToGrade', 'FromGrade', 'Action'], dtype='object')
# Columns available in META recommendations: Index(['Firm', 'ToGrade', 'FromGrade', 'Action'], dtype='object')
# Columns available in MSFT recommendations: Index(['Firm', 'ToGrade', 'FromGrade', 'Action'], dtype='object')
# Columns available in MU recommendations: Index(['Firm', 'ToGrade', 'FromGrade', 'Action'], dtype='object')
# Columns available in NFLX recommendations: Index(['Firm', 'ToGrade', 'FromGrade', 'Action'], dtype='object')
# Columns available in NVDA recommendations: Index(['Firm', 'ToGrade', 'FromGrade', 'Action'], dtype='object')
# Columns available in ORCL recommendations: Index(['Firm', 'ToGrade', 'FromGrade', 'Action'], dtype='object')
# Columns available in OVV recommendations: Index(['Firm', 'ToGrade', 'FromGrade', 'Action'], dtype='object')
# Columns available in OXY recommendations: Index(['Firm', 'ToGrade', 'FromGrade', 'Action'], dtype='object')
# Columns available in PLTR recommendations: Index(['Firm', 'ToGrade', 'FromGrade', 'Action'], dtype='object')
# Columns available in PLUG recommendations: Index(['Firm', 'ToGrade', 'FromGrade', 'Action'], dtype='object')
# Columns available in PYPL recommendations: Index(['Firm', 'ToGrade', 'FromGrade', 'Action'], dtype='object')
# Columns available in RIOT recommendations: Index(['Firm', 'ToGrade', 'FromGrade', 'Action'], dtype='object')
# Columns available in SBUX recommendations: Index(['Firm', 'ToGrade', 'FromGrade', 'Action'], dtype='object')
# Columns available in SU recommendations: Index(['Firm', 'ToGrade', 'FromGrade', 'Action'], dtype='object')
# Columns available in SU.TO recommendations: Index(['Firm', 'ToGrade', 'FromGrade', 'Action'], dtype='object')
# Columns available in TSLA recommendations: Index(['Firm', 'ToGrade', 'FromGrade', 'Action'], dtype='object')
# Columns available in TSM recommendations: Index(['Firm', 'ToGrade', 'FromGrade', 'Action'], dtype='object')
# ERROR:yfinance:404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/WCP.TO?modules=upgradeDowngradeHistory&corsDomain=finance.yahoo.com&formatted=false&symbol=WCP.TO&crumb=hupYAKrbOMB
# Columns available in WCP.TO recommendations: RangeIndex(start=0, stop=0, step=1)
# Columns available in KO recommendations: Index(['Firm', 'ToGrade', 'FromGrade', 'Action'], dtype='object')
# Columns available in HD recommendations: Index(['Firm', 'ToGrade', 'FromGrade', 'Action'], dtype='object')
# Columns available in IBM recommendations: Index(['Firm', 'ToGrade', 'FromGrade', 'Action'], dtype='object')
# Columns available in CAT recommendations: Index(['Firm', 'ToGrade', 'FromGrade', 'Action'], dtype='object')
# Columns available in CVX recommendations: Index(['Firm', 'ToGrade', 'FromGrade', 'Action'], dtype='object')
# Columns available in MCD recommendations: Index(['Firm', 'ToGrade', 'FromGrade', 'Action'], dtype='object')
# Columns available in NKE recommendations: Index(['Firm', 'ToGrade', 'FromGrade', 'Action'], dtype='object')
# Columns available in WDAY recommendations: Index(['Firm', 'ToGrade', 'FromGrade', 'Action'], dtype='object')
# Columns available in CB recommendations: Index(['Firm', 'ToGrade', 'FromGrade', 'Action'], dtype='object')
# Columns available in SIRI recommendations: Index(['Firm', 'ToGrade', 'FromGrade', 'Action'], dtype='object')
# Columns available in HEI recommendations: Index(['Firm', 'ToGrade', 'FromGrade', 'Action'], dtype='object')
# Columns available in ULTA recommendations: Index(['Firm', 'ToGrade', 'FromGrade', 'Action'], dtype='object')
# Columns available in BN recommendations: Index(['Firm', 'ToGrade', 'FromGrade', 'Action'], dtype='object')
# Columns available in V recommendations: Index(['Firm', 'ToGrade', 'FromGrade', 'Action'], dtype='object')
# Total recommendations fetched: 18269
#               GradeDate            Firm     ToGrade   FromGrade Action Stock  \
# 0   2024-08-06 16:12:26  Morgan Stanley  Overweight  Overweight   main  AAPL
# 1   2024-08-05 19:33:19         Needham         Buy         Buy   reit  AAPL
# 2   2024-08-02 17:44:09     Maxim Group        Hold        Hold   main  AAPL
# 3   2024-08-02 15:57:25      Rosenblatt         Buy         Buy   main  AAPL
# 4   2024-08-02 13:04:02         Wedbush  Outperform  Outperform   main  AAPL
# ..                  ...             ...         ...         ...    ...   ...
# 480 2012-02-09 12:25:00     Oppenheimer  Outperform               main     V
# 481 2012-02-09 12:06:00   Deutsche Bank         Buy               main     V
# 482 2012-02-09 12:05:00       Citigroup     Neutral               main     V
# 483 2012-02-09 11:45:00         Wedbush     Neutral               main     V
# 484 2012-02-08 13:05:00          Stifel         Buy               main     V
#
#      index
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ..     ...
# 480    NaN
# 481    NaN
# 482    NaN
# 483    NaN
# 484    NaN
#
# [18269 rows x 7 columns]
